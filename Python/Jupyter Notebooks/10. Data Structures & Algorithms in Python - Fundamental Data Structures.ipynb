# %% [markdown]
# # Data Structures & Algorithms in Python: Fundamental Data Structures

# %% [markdown]
# ## TODO!! An Overview of Data Structures

# %%
 # TODO!! It's all theory this one

# %%
# The Whole topic is theory!!

# %%
# Topic 11 is all practical, and how to execute this theory
